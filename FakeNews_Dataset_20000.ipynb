# %% [markdown]
# <a href="https://colab.research.google.com/github/Abishethvarman/FakeNewsDetection/blob/datasets/FakeNews_Dataset_20000.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive

# %%
# %cd /mydrive/dataset/
# Out:
# /content/gdrive/My Drive/dataset

# %%
df_reliable = pd.read_csv("Reliable.csv")
df_fake = pd.read_csv("Fake.csv")

# %%
df_reliable['isfake'] = 0
df_fake['isfake'] = 1

# %%
print(df_reliable.shape)
# Out:
# (21417, 5)

# %%
print(df_fake.shape)
# Out:
# (23481, 5)

# %%
df_fake = df_fake.drop_duplicates()

# %%
df_reliable = df_reliable.drop_duplicates()

# %%
print(df_reliable.shape)
print(df_fake.shape)
# Out:
# (21211, 5)
# (23478, 5)

# %%
target_samples = 10000
reliable_news = df_reliable[df_reliable['isfake'] == 0].sample(n=target_samples, random_state=42)
fake_news = df_fake[df_fake['isfake'] == 1].sample(n=target_samples, random_state=42)

df_adjusted = pd.concat([reliable_news, fake_news], ignore_index=True)
df_adjusted = df_adjusted.sample(frac=1, random_state=42)

# %%
df_adjusted.shape
# Out:
# (20000, 5)

# %%
df_adjusted
# Out:
#                                                    title  \
# 10650   Trump Supporters Terrorize An American Woman ...
# 2041   Trump adviser's Russia credentials come under ...
# 8668   Turkey feels betrayed over EU accession but st...
# 1114   China newspapers say call with Taiwan's Tsai s...
# 13902   Sean Hannity Just Openly Threatened Someone O...
# ...                                                  ...
# 11284  RUSSIAN AMBASSADOR Visited Obama 6 Times Durin...
# 11964   MAJOR Ad Vendor Bans Breitbart For Hate Speec...
# 5390   Jordan begins diplomatic offensive ahead of Tr...
# 860    U.S.-Russia tensions over Syria will not 'spir...
# 15795  Insider Firm ‘FlashPoint’ tied to Orlando Shoo...
#
#                                                     text       subject  \
# 10650  Donald Trump s deplorable supporters strike ag...          News
# 2041   MOSCOW (Reuters) - When Donald Trump named a l...  politicsNews
# ...

# %%
df_adjusted['label'] = df_adjusted['isfake'].map({1:'fake', 0:'real'})

# %%
df_adjusted
# Out:
#                                                    title  \
# 10650   Trump Supporters Terrorize An American Woman ...
# 2041   Trump adviser's Russia credentials come under ...
# 8668   Turkey feels betrayed over EU accession but st...
# 1114   China newspapers say call with Taiwan's Tsai s...
# 13902   Sean Hannity Just Openly Threatened Someone O...
# ...                                                  ...
# 11284  RUSSIAN AMBASSADOR Visited Obama 6 Times Durin...
# 11964   MAJOR Ad Vendor Bans Breitbart For Hate Speec...
# 5390   Jordan begins diplomatic offensive ahead of Tr...
# 860    U.S.-Russia tensions over Syria will not 'spir...
# 15795  Insider Firm ‘FlashPoint’ tied to Orlando Shoo...
#
#                                                     text       subject  \
# 10650  Donald Trump s deplorable supporters strike ag...          News
# 2041   MOSCOW (Reuters) - When Donald Trump named a l...  politicsNews
# ...

# %%
df_adjusted.to_csv('fake-20000-SA.csv')
